# %%
#Conectar com o Google Drive

from google.colab import drive
drive.mount('/content/drive')

#Conectando o ambiente ao Google Drive
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/2-base_10052023.xlsx - Sheet1.csv')
df
# Out:
#             id        "dataPublicada"           "autor"  \
# 0            1  "2022-03-04 09:38:00"        v8_capital
# 1            2  "2022-03-04 09:29:00"     winthegame_of
# 2            3  "2022-03-04 09:20:00"        marta_bego
# 3            4  "2022-03-04 08:36:00"        lmviapiana
# 4            5  "2022-03-03 21:10:00"      vanilson_dos
# ...        ...                    ...               ...
# 12350  3044013  "2022-11-30 11:51:00"       onixcapital
# 12351  3044212  "2022-11-30 12:25:00"  amgcapitalinvest
# 12352  3044213  "2022-11-30 12:18:00"     jayipacderota
# 12353  3044412  "2022-11-30 12:50:00"   moinho_cultural
# 12354  3045012  "2022-11-30 14:27:00"         bfmarilia
#
#                                                  "texto" "sentimento"  \
# 0      Confira os resultados dos nossos fundos no mês...      NEUTRAL
# 1      A Alvarez & Marsal estará conosco no Sportainm...      NEUTRAL
# 2      #Repost btgpactual with make_repost ・・・ Entend...      NEUTRAL
# ...

# %%
df['"anomalia"'].value_counts()
# Out:
# 0    9608
# 1    2747
# Name: "anomalia", dtype: int64

# %%
df_filtered = df.loc[df['"autor"'] == 'btgpactual']
df_filtered
# Out:
#            id        "dataPublicada"     "autor"  \
# 5043  1714818  "2022-07-11 22:56:00"  btgpactual
# 5044  1714819  "2022-07-11 22:56:00"  btgpactual
# 5046  1714821  "2022-07-11 22:39:00"  btgpactual
# 5047  1714822  "2022-07-11 22:39:00"  btgpactual
# 5048  1714823  "2022-07-11 22:39:00"  btgpactual
# ...       ...                    ...         ...
# 5601  1734091  "2022-07-14 13:42:00"  btgpactual
# 5602  1734092  "2022-07-14 13:34:00"  btgpactual
# 5603  1734093  "2022-07-14 13:34:00"  btgpactual
# 5604  1734094  "2022-07-14 13:34:00"  btgpactual
# 5605  1734095  "2022-07-14 13:34:00"  btgpactual
#
#                                                 "texto" "sentimento"  \
# 5043             Olá! Tudo bem? Como podemos te ajudar?      NEUTRAL
# 5044            Olá! Tudo bem?  Como podemos te ajudar?      NEUTRAL
# 5046  Olá! Tudo bem?   Poderia nos encaminhar um pri...      NEUTRAL
# 5047  Recomendamos a todos os nossos clientes que ti...     NEGATIVE
# ...

# %% [markdown]
# Pq os "linkPost" só redirecionam para post não do BTG?

# %%
df_filtered2 = df.loc[df['"contemHyperlink"'] == 1]
df_filtered2
# Out:
#             id        "dataPublicada"                  "autor"  \
# 13          14  "2022-03-03 18:23:00"      nextepinvestimentos
# 19          20  "2022-03-03 15:31:00"                 ledmello
# 38          39  "2022-03-02 13:46:00"           amaitelourenco
# 46          47  "2022-03-02 09:52:00"       blackrocksstartups
# 407      58465  "2022-02-23 08:41:00"        vouficarriconapaz
# ...        ...                    ...                      ...
# 11349  2824306  "2022-11-07 03:52:00"         sabarainformacao
# 11433  2836969  "2022-11-08 12:36:00"               mmrs.paulo
# 11661  2880225  "2022-11-13 00:55:00"                jessniloo
# 11680  2889725  "2022-11-14 00:56:00"  focuscapital_investment
# 11764  2923074  "2022-11-17 12:29:00"         amgcapitalinvest
#
#                                                  "texto" "sentimento"  \
# 13     Com o objetivo de democratizar o acesso do inv...     POSITIVE
# ...

# %% [markdown]
# "Processado" é inútil pois o valor é sempre 0

# %%
df.describe()
# Out:
#                  id    "anomalia"  "probabilidadeAnomalia"  "processado"  \
# count  1.235500e+04  12355.000000             12355.000000       12355.0
# mean   1.757789e+06      0.222339                37.325698           0.0
# std    7.967971e+05      0.415835                16.374936           0.0
# min    1.000000e+00      0.000000                 7.000000           0.0
# 25%    1.314377e+06      0.000000                24.000000           0.0
# 50%    1.783879e+06      0.000000                37.000000           0.0
# 75%    2.388714e+06      0.000000                48.000000           0.0
# max    3.045012e+06      1.000000               100.000000           0.0
#
#        "contemHyperlink"
# count       12355.000000
# mean            0.005423
# std             0.073443
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max             1.000000

# %%
df = df.drop('"processado"', axis=1)
df
# Out:
#             id        "dataPublicada"           "autor"  \
# 0            1  "2022-03-04 09:38:00"        v8_capital
# 1            2  "2022-03-04 09:29:00"     winthegame_of
# 2            3  "2022-03-04 09:20:00"        marta_bego
# 3            4  "2022-03-04 08:36:00"        lmviapiana
# 4            5  "2022-03-03 21:10:00"      vanilson_dos
# ...        ...                    ...               ...
# 12350  3044013  "2022-11-30 11:51:00"       onixcapital
# 12351  3044212  "2022-11-30 12:25:00"  amgcapitalinvest
# 12352  3044213  "2022-11-30 12:18:00"     jayipacderota
# 12353  3044412  "2022-11-30 12:50:00"   moinho_cultural
# 12354  3045012  "2022-11-30 14:27:00"         bfmarilia
#
#                                                  "texto" "sentimento"  \
# 0      Confira os resultados dos nossos fundos no mês...      NEUTRAL
# 1      A Alvarez & Marsal estará conosco no Sportainm...      NEUTRAL
# 2      #Repost btgpactual with make_repost ・・・ Entend...      NEUTRAL
# ...
